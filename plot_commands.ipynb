# %%
import similarityGraph6 as s
import pickle
import aggregate_dist as a
"""
Requirements:
numpy
networkx
scipy\usepackage{hyperref}
scikitlearn
"""
# Out:
# '\nRequirements:\nnumpy\nnetworkx\nscipy\\usepackage{hyperref}\nscikitlearn\n'

# %%
# %matplotlib inline

# %%
#data extracted by tinder api wrapper for 4km radius
pickl = pickle.load(open("BiodictData/biodictdist4.pickle", "rb"))
# histogram
s.construct(pickl, 1, 2, 'h');
# Out:
# /root/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes/_subplots.py:69: MatplotlibDeprecationWarning: The use of 0 (which ends up being the _last_ sub-plot) is deprecated in 1.4 and will raise an error in 1.5
#   mplDeprecation)

# %%
# Scatter plot matric of nodes on eigen vectors kspace for k = 5
# k = 5 is also hardcoded but can be easily changed in the code to update the plots
s.construct(pickl, 1, 2, 'e');

# %%
#Spring network again coloured on 3 clusters (which is hardcoded atm)
#but ca be easily changed in the code
s.construct(pickl, 1, 2, 's');

# %%
# projection on eigenvectors 1 and 2 for 3 cluster couloring
s.construct(pickl, 1, 2, 'c');

# %%
# aggregate distance vs raddi plot for radius in 4km to 64km by increments of 4km
a.main('r')

# %%
# aggregate distance vs cluster number for different raddi (each color is a different radii)
a.main('c')
# A couple of things are hardcoded. With a bit more time and less coursework clashes we
# could have wrapped things up a bit more nicely (STN, MLPR and CT are all close to each other)
