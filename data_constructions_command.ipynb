# %%
import pickle
import tinderbot as t
pickl = pickle.load(open("giganticData", "rb"))
print pickl
# Out:
# {'graphdist16': <networkx.classes.graph.Graph object at 0x7f308c3cdb10>, 'graphdist48': <networkx.classes.graph.Graph object at 0x7f3092a48ed0>, 'graphdist12': <networkx.classes.graph.Graph object at 0x7f3092a48f90>, 'graphdist64': <networkx.classes.graph.Graph object at 0x7f30929d60d0>, 'graphdist52': <networkx.classes.graph.Graph object at 0x7f30929d6110>, 'graphdist40': <networkx.classes.graph.Graph object at 0x7f30929cddd0>, 'graphdist60': <networkx.classes.graph.Graph object at 0x7f308c1a2650>, 'graphdist56': <networkx.classes.graph.Graph object at 0x7f308c3cd510>, 'graphdist44': <networkx.classes.graph.Graph object at 0x7f30929cde50>, 'graphdist28': <networkx.classes.graph.Graph object at 0x7f30929cde90>, 'graphdist8': <networkx.classes.graph.Graph object at 0x7f30929cded0>, 'graphdist36': <networkx.classes.graph.Graph object at 0x7f30929cdf10>, 'graphdist20': <networkx.classes.graph.Graph object at 0x7f30929cdf50>, 'graphdist4': <networkx.classes.graph.Graph object at 0x7f3092
# ...

# %%
t.main() #Here we are printing the data for 5 of our graphs(dict4,dict8,dict16,dict32,dict64); in reality we use another 11 dictionaries
# Out:
# Reaches this far
# ...
